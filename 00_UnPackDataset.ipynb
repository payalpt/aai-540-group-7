# %%
# !ls Datasets/
# Out:
# EmotionsAudio.zip  cleaned_age.csv  cleaned_emotion.csv  cleaned_gender.csv

# %%
# !ls -lh Datasets/EmotionsAudio.zip
# Out:
# -rw-r--r--. 1 sagemaker-user users 1.2G Jan 19 17:15 Datasets/EmotionsAudio.zip

# %%
import zipfile
with zipfile.ZipFile('Datasets/EmotionsAudio.zip', 'r') as zip_ref:
    zip_ref.extractall('Datasets/')
