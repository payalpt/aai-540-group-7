# %% [markdown]
# # EDA

# %%
#Add connection to Athena tables here later if needed

# %%
#Import libraries
import pandas as pd

# %%
#Start by reading in combined emotion data
df_all = pd.read_csv("Datasets/Combined_Emotion_Data.csv")
df_all.head()
# Out:
#    row_id s3_key_s  meanfreq        sd    median       q25       q75  \
# 0       0        1  0.181338  0.060495  0.187476  0.126197  0.233586
# 1       1        2  0.186897  0.062260  0.195070  0.130847  0.243987
# 2       2        3  0.189102  0.062901  0.204945  0.131422  0.249978
# 3       4        5  0.183036  0.060051  0.174115  0.129949  0.236967
# 4       5        6  0.168793  0.057910  0.156266  0.116783  0.216326
#
#         iqr      skew      kurt  ...  centroid   meanfun    minfun    maxfun  \
# 0  0.107389  0.869088  2.863717  ...  0.181338  0.137742  0.023022  0.271186
# 1  0.113140  1.191767  3.878650  ...  0.186897  0.121811  0.018412  0.271186
# 2  0.118556  1.312690  4.589995  ...  0.189102  0.123758  0.083333  0.262295
# 3  0.107017  1.096409  3.680995  ...  0.183036  0.128469  0.044693  0.258065
# 4  0.099543  1.386837  5.031744  ...  0.168793  0.109720  0.022472  0.235294
#
#     meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %% [markdown]
# ## Additional EDA
