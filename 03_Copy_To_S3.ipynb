# %% [markdown]
# # Copy Files to S3

# %%
# %store -r setup_dependencies_passed

# %%
try:
    setup_dependencies_passed
except NameError:
    print("+++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN ALL NOTEBOOKS IN THE SETUP FOLDER FIRST. You are missing Setup Dependencies.")
    print("+++++++++++++++++++++++++++++++")

# %%
print(setup_dependencies_passed)
# Out:
# True

# %%
# %store -r setup_s3_bucket_passed

# %%
try:
    setup_s3_bucket_passed
except NameError:
    print("+++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN ALL NOTEBOOKS IN THE SETUP FOLDER FIRST. You are missing Setup S3 Bucket.")
    print("+++++++++++++++++++++++++++++++")

# %%
print(setup_s3_bucket_passed)
# Out:
# True

# %%
if not setup_dependencies_passed:
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN ALL NOTEBOOKS IN THE SETUP FOLDER FIRST. You are missing Setup Dependencies.")
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
if not setup_s3_bucket_passed:
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    print("[ERROR] YOU HAVE TO RUN ALL NOTEBOOKS IN THE SETUP FOLDER FIRST. You are missing Setup S3 Bucket.")
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")

# %%
import boto3
import sagemaker
import pandas as pd

sess = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name
account_id = boto3.client("sts").get_caller_identity().get("Account")

sm = boto3.Session().client(service_name="sagemaker", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %% [markdown]
# ## Synch Data to S3 Bucket

# %%
# Sync folder to S3 Bucket using dynamic bucket variable
# !aws s3 sync Datasets/ s3://{bucket}/audio/Datasets/ --only-show-errors --no-progress --size-only

# %%
s3_private_path_wav = f"s3://{bucket}/audio/Datasets/"

# %%
# %store s3_private_path_wav
# Out:
# Stored 's3_private_path_wav' (str)

# %% [markdown]
# ## List Files in Team Private S3 Bucket

# %%
print(s3_private_path_wav)
# Out:
# s3://sagemaker-us-east-1-218117716191/audio/Datasets/

# %%
# !aws s3 ls $s3_private_path_wav/

# %%
from IPython.core.display import display, HTML

# Use dynamic bucket from session (already defined earlier in notebook)
prefix = "audio/Datasets/"

display(
    HTML(
        f'<b>Review <a target="_blank" href="https://s3.console.aws.amazon.com/s3/buckets/{bucket}/{prefix}/?region={region}">S3 Bucket Data</a></b>'
    )
)

# %% [markdown]
# ## Store Variables for the Next Notebooks

# %%
# %store
# Out:
# Stored variables and their in-db values:
# s3_file_path_wav                      -> 's3://sagemaker-us-east-1-218117716191/audio/Datas
# s3_private_path_wav                   -> 's3://sagemaker-us-east-1-218117716191/audio/Datas
# setup_dependencies_passed             -> True
# setup_s3_bucket_passed                -> True

# %% [markdown]
# ## Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
